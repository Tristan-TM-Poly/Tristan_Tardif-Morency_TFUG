# %% [markdown]
# # 01a — I/O Standards Demo
# Démontre l’utilisation des étalons synthétiques/réels et la lecture des métadonnées.

# %%
import os, sys, json
sys.path.append(os.path.join("..", "src"))
from raman_ai.io.standards import load_reference_spectra_mode

root = os.path.join("..","data","standards")
specs_syn, metas_syn = load_reference_spectra_mode(root, mode="synthetic")
specs_syn_names = [s.name for s in specs_syn]
specs_syn_names, list(metas_syn.keys())[:2]

# %%
# Si des étalons réels sont déposés dans data/standards/real_templates/
specs_real, metas_real = load_reference_spectra_mode(root, mode="real")
[(s.name, len(s.wavenumber)) for s in specs_real][:5]
